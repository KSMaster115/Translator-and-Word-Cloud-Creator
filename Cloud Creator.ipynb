# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %matplotlib inline

# %%
# For Presentation Populating
from pptx import Presentation
from pptx.util import Cm
from pptx.enum.text import MSO_ANCHOR, MSO_AUTO_SIZE
from pptx.dml.color import RGBColor
from pptx.enum.dml import MSO_THEME_COLOR
from pptx.util import Pt

# %%
pd.options.display.max_rows = 100

# %% [markdown]
# ### Active Functions

# %%
def cleaner(df,start):
    # This function aims to tokenise the set, filter out stopwords/punctuations ,etc. and translate any remaining words not captured by earlier machine translations. 
    # Will be assigned back to individual cell locations after
    
    # Create a temporary dict within the function to work on
    tempdf = df.copy()

    # lowercase each cell's words. Token out into individual words, returning the list container to the cell. Only if the cell is a str. Otherwise return 0 to the cell.
    tempdf.iloc[:,start:]= tempdf.iloc[:,start:].map(lambda x: nltk.word_tokenize(x.lower()) if isinstance(x, str) else 0)

    # Filter out stopwords if cell is a list (due to tokenisation step) else return unedited cell value
    # stop_words is a global set containing the words to filter. Has additional items such as punctuation from the base stopwords form
    tempdf.iloc[:,start:] = tempdf.iloc[:,start:].map(lambda x: [w for w in x if not w in stop_words]
                                         if isinstance(x, list) else x)

    # Search if cell word is in dict of translated word. Only if cell is a list (due to tokenisation step) otherwise return unedited cell value.
    # translated_word is a global dict containing the word as keys and translations of the words as values
    #tempdf.iloc[:,start:] = tempdf.iloc[:,start:].map(lambda x: [translated_words[w] if w in translated_words.keys() else w for w in x]
                                          #if isinstance(x, list) else x)
      
    return tempdf

# %%
# generating list from nested list
def wordlistnestgen(df, cols):
    
    # Create a temporary dict within the function to work on
    tempdf = df.copy()
    tempdf = tempdf.iloc[:,cols]

    # Create a full list of all words in all cells
    list_words = [item for item in tempdf.map(lambda x: x if isinstance(x, list) else None).to_numpy().flatten() if item is not None]

    return list_words

# %%
# Creating word strings for cloud from list
def stringgetter(df):

    #flatten df to list
    flat_list = [
        x
        for xs in df
        for x in xs]

    # strip of whitespaces
    for x in flat_list:
        x = x.strip()

    # make to stroig
    s = " ".join(flat_list)

    return s

# %%
# generate df to check the words
def wordlister(df, start, cols = list(range(5,36))):
    tempdf = cleaner(df,5)
    listwords = wordlistnestgen(tempdf, cols)

    flat_list = [
        x
        for xs in listwords
        for x in xs]
    
    dflist = pd.Series(flat_list)
    counts = dflist.value_counts()
    dfcounts = counts.reset_index()

    return dfcounts

# %%
# Generate text to copy-paste and the table of text in the cloud
def textcheck(df, start, cols):

    listwords = wordlister(df, start, cols)
    
    #print top 5 words in the format indicated
    strlist = ''
    for i, r in listwords.iloc[0:5].iterrows():
        strlist += f'{r['index'].replace('_', ' ').capitalize()} | '

    # return list for access later
    return listwords, strlist

# %%
def cloudgenerator(df, start, cols, hsl, filename = 'test', size = 50, width = 1600, height = 800, dirname = 'test', wordlist = 'NA'):  
    tempdf = cleaner(df, start)
    listwords = wordlistnestgen(tempdf, cols)
    cloudstring = stringgetter(listwords)

    # tuple unpack hsl values
    hue, sat, lumibright, lumirand = hsl
    if len(lumirand) == 2:
        hue2, sat2 = hue, sat
        lumil, lumiu = lumirand
    else:
        hue2, sat2, lumil, lumiu = lumirand
    
    
    # Set custom colour. The other args are currently unused but could be utilised to affect the color scheme. e.g. hue = len(word) * basehue to use word length to affect hue
    def color_func(word, font_size, position,orientation,random_state=None, **kwargs):
        if word in wordlist:
            return(f"hsl({hue}, {sat}%, {lumibright}%)")
        else:
            return(f"hsl({hue2}, {sat2}%, {np.random.randint(lumil , lumiu)}%)")
        
    wordcloud = WordCloud(font_path = 'Lato-Regular.ttf',width=width, height=height, collocations=False, max_words = size, background_color = 'white', normalize_plurals = False, relative_scaling = 0.3).generate(cloudstring)

    # Display the generated image:
    plt.figure(figsize=(20,10))
    plt.imshow(wordcloud.recolor(color_func = color_func), interpolation='bilinear')
    plt.axis("off")
    plt.savefig(f'Clouds/{dirname}/{filename}.png',bbox_inches='tight')
    plt.close()

# %%
def cloudplacer(slidekey, wordcloud, positionkey):
    slide = prs.slides.get(slidekey)  #Get the slide
    if '_all' in positionkey:
        pic = slide.shapes.add_picture(wordcloud,left=Cm(2.59),top=Cm(2.03),width=Cm(20.22),height=Cm(10.24))
    elif '_sweet' in positionkey:
        pic = slide.shapes.add_picture(wordcloud,left=Cm(1.93),top=Cm(2.03),width=Cm(20.22),height=Cm(10.24))
    elif '_UA' in positionkey:
        pic = slide.shapes.add_picture(wordcloud,left=Cm(1.12),top=Cm(5.3),width=Cm(6.17),height=Cm(6.78))
    elif '_dressing' in positionkey:
        pic = slide.shapes.add_picture(wordcloud,left=Cm(9.62),top=Cm(5.3),width=Cm(6.17),height=Cm(6.78))
    else:
        pic = slide.shapes.add_picture(wordcloud,left=Cm(18.12),top=Cm(5.3),width=Cm(6.17),height=Cm(6.78))

# %%
# For the text on the 'Overall' Slide
def textplacer(slidekey, text, boxposition, color):

    slide = prs.slides.get(slidekey)
    left, top, width, height, bold = boxposition
    R, G, B = color
    
    shape = slide.shapes.add_textbox(Cm(left),Cm(top),Cm(width),Cm(height))
    text_frame = shape.text_frame
    text_frame.margin_top = Cm(0.13)
    text_frame.margin_bottom = Cm(0.13)
    text_frame.margin_left = Cm(0.25)
    text_frame.vertical_anchor = MSO_ANCHOR.TOP
    text_frame.word_wrap = True
    text_frame.auto_size = MSO_AUTO_SIZE.SHAPE_TO_FIT_TEXT
    
    p = text_frame.add_paragraph()
    
    run1 = p.add_run()
    run1.text = 'Top 5 Flavours: '
    run1.font.name = 'Lato Light'
    run1.font.size = Pt(10)
    run1.font.bold = True
    run1.font.color.rgb = RGBColor(33, 33, 33)
    
    run2 = p.add_run()
    run2.text = text
    run2.font.name = 'Lato Light'
    run2.font.size = Pt(10)
    run2.font.bold = bold
    run2.font.color.rgb = RGBColor(R, G, B) # TO EDIT

# %% [markdown]
# ## Code

# %% [markdown]
# ### Creating the different df for global, regions and country

# %%
df = pd.read_excel(r"Translated.xlsx", sheet_name = "A1")

# %%
GLOBALdf = df.copy()
APACdf = df[df['Regions'] == 'APAC'].copy()
EUROPEdf = df[df['Regions'] == 'EUROPE'].copy()
LATAMdf = df[df['Regions'] == 'LATAM'].copy()
CHINAdf = df[df['hCountry'] == 1].copy()
INDONESIAdf = df[df['hCountry'] == 2].copy()
INDIAdf = df[df['hCountry'] == 3].copy()
UKdf = df[df['hCountry'] == 4].copy()
GERMANYdf = df[df['hCountry'] == 5].copy()
FRANCEdf = df[df['hCountry'] == 6].copy()
BRAZILdf = df[df['hCountry'] == 7].copy()
MEXICOdf = df[df['hCountry'] == 8].copy()
USdf = df[df['hCountry'] == 9].copy()
MOROCCOdf = df[df['hCountry'] == 10].copy()

# %%
dfdict = {'GLOBAL':GLOBALdf
          ,'APAC':APACdf
          ,'EUROPE':EUROPEdf
          ,'LATAM':LATAMdf
          ,'CHINA':CHINAdf
          ,'INDONESIA':INDONESIAdf
          ,'INDIA':INDIAdf
          ,'UK':UKdf
          ,'GERMANY':GERMANYdf
          ,'FRANCE':FRANCEdf
          ,'BRAZIL':BRAZILdf
          ,'MEXICO':MEXICOdf
          ,'US':USdf
          ,'MOROCCO':MOROCCOdf
}

# %% [markdown]
# ### Directions

# %%
# set stopwords
stop_words = set(stopwords.words('english'))
addstopwords = [' ,', ',',"n't",'remember', '.',' .', 'know', 'much', 'sensation', 'gives', 'color', 'colour','💋','/','-','🥗','🍓','🍔','😘','🍡','🍬', 'seem','seems','taste','tastes','food','powder','look','less','bit','little','something','somewhat','lot','maybe','rather','feel','feels',
               'may','made', 'sense','must', 'like', 'little', 'more', 'sauce', 'se', 'le']
stop_words.update(addstopwords)

# %%
# dict to store generation instructions
# order is {colour_scope: (columns, hsl(hue, sat, lumi luminrand(hue2 (optional), sat2(optional), lumi_lower, Lumi_upper), max_words, width, height, colorNumberCode)}
directions = {# PINK
             '_pink_all':([5,14,23], (340, 100, 59.8, (78, 80)), 50, 1600, 800, 1),
             '_pink_UA':([5], (340, 100, 59.8, (78, 80)), 25, 1000, 1100, 1),
             '_pink_dressing':([14], (340, 100, 59.8, (78, 80)), 25, 1000, 1100, 1),
             '_pink_season':([23], (340, 100, 59.8, (78, 80)), 25, 1000, 1100, 1),
             # YELLOW
             '_yellow_all':([6,15,24], (45, 100, 50, (80, 90)), 50, 1600, 800, 2),
             '_yellow_UA':([6], (45, 100, 50, (80, 90)), 25, 1000, 1100, 2),
             '_yellow_dressing':([15], (45, 100, 50, (80, 90)), 25, 1000, 1100, 2),
             '_yellow_season':([24], (45, 100, 50, (80, 90)), 25, 1000, 1100, 2),
             # BLUE
             '_blue_all':([7,16,25], (235, 100, 50, (80, 90)), 50, 1600, 800, 3),
             '_blue_UA':([7], (235, 100, 50, (80, 90)), 25, 1000, 1100, 3),
             '_blue_dressing':([16], (235, 100, 50, (80, 90)), 25, 1000, 1100, 3),
             '_blue_season':([25], (235, 100, 50, (80, 90)), 25, 1000, 1100, 3),
             # PURPLE
             '_purple_all':([8,17,26], (264, 31.4, 52, (264, 31.1, 76, 77)), 50, 1600, 800, 4),
             '_purple_UA':([8], (264, 31.4, 52, (264, 31.1, 76, 77)), 25, 1000, 1100, 4),
             '_purple_dressing':([17], (264, 31.4, 52, (264, 31.1, 76, 77)), 25, 1000, 1100, 4),
             '_purple_season':([26], (264, 31.4, 52, (264, 31.1, 76, 77)), 25, 1000, 1100, 4),
             # ORANGE
             '_orange_all':([9,18,27], (30, 100, 50, (80, 90)), 50, 1600, 800, 5),
             '_orange_UA':([9], (30, 100, 50, (80, 90)), 25, 1000, 1100, 5),
             '_orange_dressing':([18], (30, 100, 50, (80, 90)), 25, 1000, 1100, 5),
             '_orange_season':([27], (30, 100, 50, (80, 90)), 25, 1000, 1100, 5),
             # BROWN
             '_brown_all':([10,19,28], (30, 100, 25, (80, 90)), 50, 1600, 800, 6),
             '_brown_UA':([10], (30, 100, 25, (80, 90)), 25, 1000, 1100, 6),
             '_brown_dressing':([19], (30, 100, 25, (80, 90)), 25, 1000, 1100,6),
             '_brown_season':([28], (30, 100, 25, (80, 90)), 25, 1000, 1100, 6),
             # BLACK
             '_black_all':([11,20,29],(0, 0, 0, (60, 70)), 50, 1600, 800, 7),
             '_black_UA':([11],(0, 0, 0, (60, 70)), 25, 1000, 1100, 7),
             '_black_dressing':([20], (0, 0, 0, (60, 70)), 25, 1000, 1100, 7),
             '_black_season':([29],(0, 0, 0, (60, 70)), 25, 1000, 1100, 7),
             # RED
             '_red_all':([12,21,30],(0, 100, 50, (70, 80)), 50, 1600, 800, 8),
             '_red_UA':([12],(0, 100, 50, (70, 80)), 25, 1000, 1100, 8),
             '_red_dressing':([21],(0, 100, 50, (70, 80)), 25, 1000, 1100, 8),
             '_red_season':([30],(0, 100, 50, (70, 80)), 25, 1000, 1100, 8),
             # GREEN
             '_green_all':([13,22,31],(143, 76.5, 33.3, (120, 38.2, 73, 74)), 50, 1600, 800, 9),
             '_green_UA':([13],(143, 76.5, 33.3, (120, 38.2, 73, 74)), 25, 1000, 1100, 9),
             '_green_dressing':([22],(143, 76.5, 33.3, (120, 38.2, 73, 74)), 25, 1000, 1100, 9),
             '_green_season':([31],(143, 76.5, 33.3, (120, 38.2, 73, 74)), 25, 1000, 1100, 9),
             # SWEET CATEGORIES
             '_blue_sweet':([32], (235, 100, 50, (80, 90)), 50, 1600, 800, 3),
             '_pink_sweet':([33], (340, 100, 59.8, (78, 80)), 50, 1600, 800, 1),
             '_orange_sweet':([34], (30, 100, 50, (80, 90)), 50, 1600, 800, 5),
             '_red_sweet':([35],(0, 100, 50, (70, 80)), 50, 1600, 800, 8)}

# %%
pptdirection = {2:['_pink_all'],
             3:['_pink_UA', '_pink_dressing', '_pink_season'],
             # YELLOW
             4:['_yellow_all'],
             5:['_yellow_UA', '_yellow_dressing', '_yellow_season'],
             # BLUE
             6:['_blue_all'],
             7:['_blue_UA', '_blue_dressing', '_blue_season'],
             # PURPLE
             8:['_purple_all'],
             9:['_purple_UA', '_purple_dressing', '_purple_season'],
             # ORANGE
             10:['_orange_all'],
             11:['_orange_UA', '_orange_dressing', '_orange_season'],
             # BROWN
             12:['_brown_all'],
             13:['_brown_UA', '_brown_dressing', '_brown_season'],
             # BLACK
             14:['_black_all'],
             15:['_black_UA', '_black_dressing', '_black_season'],
             # RED
             16:['_red_all'],
             17:['_red_UA', '_red_dressing', '_red_season'],
             # GREEN
             18:['_green_all'],
             19:['_green_UA', '_green_dressing', '_green_season'],
             # SWEET CATEGORIES
             22:['_blue_sweet'],
             21:['_pink_sweet'],
             23:['_orange_sweet'],
             24:['_red_sweet']
               }

colordirections = {'pink': (255,102,204),
                   'yellow': (199, 149, 0),
                   'blue': (3, 104, 156),
                   'purple':(54, 0, 163),
                   'orange':(237, 129, 22),
                   'brown':(112, 56, 0),
                   'black':(33, 33, 33),
                   'red':(193, 30, 50),
                   'green':(83, 129, 70)
                  }

boxdirections = {'all':(0.5, 12.27, 16.87, 1.37, True),
                 'sweet':(0.5, 12.27, 16.87, 1.37, True),
                 'UA':(0.03, 12.27, 8.33, 1.37, False),
                 'dressing':(8.53, 12.27, 8.33, 1.37, False),
                 'season':(17.03, 12.27, 8.33, 1.37, False)
                }

# %% [markdown]
# ## Generating word cloud and Populating the PPTs

# %%
# Main Programme
startcol = 5

# dictionary to store the listnames for access later if want to check
var_names = {}
ppttext = {}

for name, df in dfdict.items():
    for k,v in directions.items():
        # print copy-paste text and store list for access later in needed
        tempdf, pptstring =  textcheck(df, start = startcol, cols = v[0])
        var_names[name+k] = tempdf
        ppttext[name+k] = pptstring
    
        # generate and save cloud as png
        cloudgenerator(df, start = startcol, cols = v[0] , hsl = v[1], filename = name+k, size = v[2], width = v[3], height = v[4], dirname = name, wordlist = (tempdf.iloc[0:5,0]).tolist())


    prs = Presentation(rf'Submissions\Food Colouring_WordCloud_{name}.pptx')
    
    page_id = {i+1 : slide.slide_id for i, slide in enumerate(prs.slides)}

    # First, go through the slides
    for k, v in page_id.items():
        # If slide index is registered as needing an image, go in
        if k in pptdirection.keys():
            # Iterate through the value (list) to place images one by one
            for i in pptdirection[k]:
                # Find and store the path of the wordcloud              
                wordcloud = rf'CLouds\{name}\{name+i}.png'
                text = ppttext[name+i]
                #place the wordcloud
                cloudplacer(v, wordcloud, i)
                #place the text
                pos = i.split('_')
                textplacer(v, ppttext[name+i], boxdirections[pos[2]], colordirections[pos[1]])
        else:
            continue

    prs.save(rf'Submissions\Food Colouring_WordCloud_{name}.pptx')

# %%
dfdicttest = {'GLOBAL':GLOBALdf
           ,'APAC':APACdf
          ,'EUROPE':EUROPEdf
          ,'LATAM':LATAMdf
          ,'CHINA':CHINAdf
          ,'INDONESIA':INDONESIAdf
          ,'INDIA':INDIAdf
          ,'UK':UKdf
          ,'GERMANY':GERMANYdf
          ,'FRANCE':FRANCEdf
          ,'BRAZIL':BRAZILdf
          ,'MEXICO':MEXICOdf
          ,'US':USdf
          ,'MOROCCO':MOROCCOdf
}

# %%
dfdictnumberstest = {'GLOBAL':1110
           ,'APAC':334
          ,'EUROPE':443
          ,'LATAM':222
          ,'CHINA':112
          ,'INDONESIA':111
          ,'INDIA':111
          ,'UK':111
          ,'GERMANY':111
          ,'FRANCE':113
          ,'BRAZIL':111
          ,'MEXICO':111
          ,'US':111
          ,'MOROCCO':108
}

# %%
startcol = 5
percentdf = {}

with pd.ExcelWriter(r'testpercentages.xlsx', engine="xlsxwriter") as writer:
    
    workbook=writer.book
    
    for regionname, df in dfdicttest.items():
        
        excelcol = 0
        
        worksheet=workbook.add_worksheet(regionname)
        writer.sheets[regionname] = worksheet
        
        for k,v in directions.items():
    
            tempdf, pptstring =  textcheck(df, start = startcol, cols = v[0])
            tempdf['Percentage'] = round((tempdf['count'] / (dfdictnumberstest[regionname]*len(v[0]))*100), 2)
            tempdf['Base Size'] = dfdictnumberstest[regionname]*len(v[0])
            tempdf.rename(columns = {'index':k}, inplace = True)
            tempdf.set_index(k, drop = True, inplace = True)

            tempdf.to_excel(writer, sheet_name = regionname, startrow=0 , startcol = excelcol) # change start col dynamically
            
            excelcol += 5

# %%
var_names['GLOBAL_pink_all']
# Out:
#              index  count
# 0            sweet    387
# 1       strawberry    246
# 2            salty    130
# 3             meat    113
# 4            fresh    111
# ..             ...    ...
# 565     unbalanced      1
# 566            fun      1
# 567  chilli_flakes      1
# 568          glaze      1
# 569     gyro_sauce      1
#
# [570 rows x 2 columns]

# %% [markdown]
# ## Tester Codes

# %%
# code to access list. Change the key as needed
var_names['global_pink_all'].head(100)

# %%
#tester prints out indiviual clouds as needed
mainname = 'test'
dftouse = APACdf
category = '_brown_all'

# load in values. change the dictionary key
cols, hsl, max_size, width, height, colorcode = directions[category]

# print copy-paste text for access

testdf2 , teststringholder = textcheck(dftouse, 5, cols = cols)
testholder = testdf2
print(teststringholder)

# generate and save cloud as png
cloudgenerator(dftouse, 5, cols, hsl, filename = f'{mainname+category}', size = max_size, width = width, height = height, dirname = mainname,  wordlist = (testdf2.iloc[0:5,0]).tolist())
# Out:
# Salty | Sweet | Strong | Barbeque | Chocolate |

# %%
def cloudgeneratorcustom(df, start, cols, hsl, filename = 'test', size = 50, width = 1600, height = 800, dirname = 'test', wordlist = 'NA'):  
    tempdf = cleaner(df, start)
    listwords = wordlistnestgen(tempdf, cols)
    cloudstring = stringgetter(listwords)

    # tuple unpack hsl values
    hue, sat, lumibright, lumirand = hsl
    if len(lumirand) == 2:
        hue2, sat2 = hue, sat
        lumil, lumiu = lumirand
    else:
        hue2, sat2, lumil, lumiu = lumirand
    
    
    # Set custom colour. The other args are currently unused but could be utilised to affect the color scheme. e.g. hue = len(word) * basehue to use word length to affect hue
    def color_func(word, font_size, position,orientation,random_state=None, **kwargs):
        if word in wordlist:
            return(f"hsl({hue}, {sat}%, {lumibright}%)")
        else:
            return(f"hsl({hue2}, {sat2}%, {np.random.randint(lumil , lumiu)}%)")
        
    wordcloud = WordCloud(font_path = 'Lato-Regular.ttf',width=width, height=height, collocations=False, max_words = size, background_color = 'white', normalize_plurals = False, relative_scaling = 0.3, max_font_size = 1600).generate(cloudstring)

    # Display the generated image:
    plt.figure(figsize=(20,10))
    plt.imshow(wordcloud.recolor(color_func = color_func), interpolation='bilinear')
    plt.axis("off")
    plt.savefig(f'Clouds/{dirname}/{filename}.png',bbox_inches='tight')
    plt.close()

# %%
#prints out indiviual clouds as needed from cutom generator
mainname = 'MOROCCO'
dftouse = MOROCCOdf
category = '_orange_sweet'


# load in values. change the dictionary key
cols, hsl, max_size, width, height, colorcode = directions[category]

# print copy-paste text for access

testdf2 , teststringholder = textcheck(dftouse, 5, cols = cols)
testholdercustom = testdf2
print(teststringholder)

# generate and save cloud as png
cloudgeneratorcustom(dftouse, 5, cols, hsl, filename = f'{mainname+category}', size = max_size, width = width, height = height, dirname = mainname,  wordlist = (testdf2.iloc[0:5,0]).tolist())
# Out:
# Orange | Lemon | Mango | Sweet | Caramel |

# %%
# For pink sweet cloud generation with new color scheme
for name, df in dfdict.items():

    mainname = name
    dftouse = df
    category = '_pink_sweet'
    
    # load in values. change the dictionary key
    cols, hsl, max_size, width, height, colorcode = directions[category]
    
    # print copy-paste text for access
    
    testdf2 , teststringholder = textcheck(dftouse, 5, cols = cols)
    testholdercustom = testdf2
    print(teststringholder)
    
    # generate and save cloud as png
    cloudgenerator(dftouse, 5, cols, hsl, filename = f'{mainname+category}', size = max_size, width = width, height = height, dirname = mainname,  wordlist = (testdf2.iloc[0:5,0]).tolist())
# Out:
# Strawberry | Sweet | Raspberry | Sugar | Cherry |
# Sweet | Strawberry | Ice cream | Fresh | Cherry |
# Strawberry | Sweet | Raspberry | Sugar | Berry |
# Strawberry | Sweet | Cherry | Candy | Gum |
# Strawberry | Sweet | Peach | Cherry | Ice cream |
# Sweet | Strawberry | Fresh | Delicious | Soft |
# Strawberry | Sweet | Ice cream | Rose | Tasty |
# Strawberry | Sweet | Raspberry | Cotton candy | Candy |
# Sweet | Strawberry | Raspberry | Fruity | Berry |
# Strawberry | Sugar | Sweet | Raspberry | Cookie |
# Strawberry | Sweet | Gum | Tutti frutti | Tasty |
# Strawberry | Sweet | Cherry | Candy | Sugar |
# Sweet | Strawberry | Cotton candy | Raspberry | Bubblegum |
# Strawberry | Sweet | Berry | Pomegranate | Sugar |

# %%
testholdercustom.head(100)
# Out:
#                index  count
# 0              sweet     46
# 1       tutti_frutti     18
# 2          blueberry     18
# 3          ice_cream     12
# 4       cotton_candy     12
# 5                gum     11
# 6         refreshing      9
# 7           blue_sky      9
# 8         artificial      9
# 9               soft      7
# 10             candy      7
# 11              good      7
# 12    food_colouring      6
# 13             anise      6
# 14             fresh      5
# 15         bubblegum      4
# 16             light      4
# 17         delicious      4
# 18         raspberry      3
# 19              mint      3
# 20             tasty      3
# 21             sugar      3
# 22          popsicle      3
# 23         chocolate      3
# 24     sophisticated      2
# 25            creamy      2
# 26        attractive      2
# 27        brigadeiro      2
# 28        nutritious      2
# 29        blackberry      2
# 30           vanilla      2
# 31            fruits      2
# 32             fruit      2
# 33           natural      2
# 34              plum      2
# 35           intense      2
# 36             grape      2
# 37              roof      1
# 38         liquorice      1
# 39             soapy      1
# 40          fantasia      1
# 41           delight      1
# 42      mildly_sweet      1
# 43        eucalyptus      1
# 44         beautiful      1
# 45           relaxed      1
# 46             tutty      1
# 47       interesting      1
# 48        nauseating      1
# 49              sour      1
# 50              soap      1
# 51         lingering      1
# 52               ceu      1
# 53            citrus      1
# 54  soft_blue_groove      1
# 55         happiness      1
# 56             spicy      1
# 57             musty      1
# 58      high_quality      1
# 59                ou      1
# 60             jelly      1
# 61            frutti      1
# 62        sweet_milk      1
# 63        very_sweet      1
# 64            strong      1
# 65            smooth      1
# 66          blue_ice      1
# 67               icy      1
# 68          frambosa      1
# 69             guava      1
# 70           vibrant      1
# 71        strawberry      1
# 72              salt      1
# 73              açaí      1
# 74               fun      1
# 75          mirtilus      1
# 76          pleasant      1
# 77              rich      1
# 78           strange      1
# 79            unique      1
# 80           gelinho      1
# 81             honey      1
# 82          lollipop      1
# 83       chewing_gum      1
# 84            fruity      1
# 85          balanced      1
# 86              cold      1
# 87          mystical      1
# 88          delicacy      1
# 89             water      1
# 90         unhealthy      1
# 91         seductive      1
# 92         different      1
# 93            chilli      1
# 94            bubble      1
# 95          oliveira      1
# 96       marshmallow      1
# 97        sour_sweet      1
# 98       blue_heaven      1
# 99            cooler      1

# %%
#prints out indiviual clouds as needed from base generator
mainname = 'GERMANY'
dftouse =GERMANYdf
category = '_pink_sweet'

# load in values. change the dictionary key
cols, hsl, max_size, width, height, colorcode = directions[category]

# print copy-paste text for access

testdf2 , teststringholder = textcheck(dftouse, 5, cols = cols)
testholder = testdf2
print(teststringholder)

# generate and save cloud as png
cloudgenerator(dftouse, 5, cols, hsl, filename = f'{mainname+category}', size = max_size, width = width, height = height, dirname = mainname,  wordlist = (testdf2.iloc[0:5,0]).tolist())
# Out:
# Sweet | Strawberry | Raspberry | Fruity | Berry |

# %%
testholder.sort_values(['count','index'],ascending = [False, True]).reset_index().head(100)
# Out:
#     level_0             index  count
# 0         0             sweet     46
# 1         2         blueberry     18
# 2         1      tutti_frutti     18
# 3         4      cotton_candy     12
# 4         3         ice_cream     12
# 5         5               gum     11
# 6         8        artificial      9
# 7         7          blue_sky      9
# 8         6        refreshing      9
# 9        10             candy      7
# 10       11              good      7
# 11        9              soft      7
# 12       13             anise      6
# 13       12    food_colouring      6
# 14       14             fresh      5
# 15       15         bubblegum      4
# 16       17         delicious      4
# 17       16             light      4
# 18       23         chocolate      3
# 19       19              mint      3
# 20       22          popsicle      3
# 21       18         raspberry      3
# 22       21             sugar      3
# 23       20             tasty      3
# 24       26        attractive      2
# 25       29        blackberry      2
# 26       27        brigadeiro      2
# 27       25            creamy      2
# 28       32             fruit      2
# 29       31            fruits      2
# 30       36             grape      2
# 31       35           intense      2
# 32       33           natural      2
# 33       28        nutritious      2
# 34       34              plum      2
# 35       24     sophisticated      2
# 36       30           vanilla      2
# 37       73              açaí      1
# 38       85          balanced      1
# 39       44         beautiful      1
# 40       98       blue_heaven      1
# 41       66          blue_ice      1
# 42       94            bubble      1
# 43       52               ceu      1
# 44      100          cheerful      1
# 45       83       chewing_gum      1
# 46       93            chilli      1
# 47       53            citrus      1
# 48       86              cold      1
# 49       99            cooler      1
# 50       88          delicacy      1
# 51       41           delight      1
# 52       92         different      1
# 53       43        eucalyptus      1
# 54       40          fantasia      1
# 55       68          frambosa      1
# 56       84            fruity      1
# 57       61            frutti      1
# 58       74               fun      1
# 59       80           gelinho      1
# 60       69             guava      1
# 61       55         happiness      1
# 62       58      high_quality      1
# 63       81             honey      1
# 64      104               ice      1
# 65       67               icy      1
# 66       47       interesting      1
# 67       60             jelly      1
# 68      102             juice      1
# 69       51         lingering      1
# 70       38         liquorice      1
# 71       82          lollipop      1
# 72       96       marshmallow      1
# 73       42      mildly_sweet      1
# 74       75          mirtilus      1
# 75       57             musty      1
# 76       87          mystical      1
# 77       48        nauseating      1
# 78       95          oliveira      1
# 79       59                ou      1
# 80       76          pleasant      1
# 81      103         processed      1
# 82       45           relaxed      1
# 83       77              rich      1
# 84       37              roof      1
# 85       72              salt      1
# 86       91         seductive      1
# 87       65            smooth      1
# 88       50              soap      1
# 89       39             soapy      1
# 90       54  soft_blue_groove      1
# 91       49              sour      1
# 92       97        sour_sweet      1
# 93       56             spicy      1
# 94       78           strange      1
# 95       71        strawberry      1
# 96       64            strong      1
# 97       62        sweet_milk      1
# 98      101             trust      1
# 99       46             tutty      1

# %%
testdf2
# Out:
#              index  count
# 0     black_pepper     62
# 1           pepper     26
# 2           strong     17
# 3           bitter     16
# 4            tasty     14
# ..             ...    ...
# 140  chilli_powder      1
# 141        earthly      1
# 142          fungs      1
# 143        toasted      1
# 144        mexican      1
#
# [145 rows x 2 columns]

# %% [markdown]
# ## Archive

# %% [raw]
# # LATEST VERSION
# def wordlistgen(df, start):
#     # This function aims to return a list of words so that 2-word words can be manually detected for a later function to add an underscore between them so tokenization recognises it as one word.
#
#     # Create a temporary dict within the function to work on
#     tempdf = df.copy()
#
#     # Create new column to hold split values
#     # lowercase each cell's words and split by ',', returning the list container to the cell. Only if the cell is a str. Otherwise return 0 to the cell.
#     tempdf.iloc[:,start:] = tempdf.iloc[:,start:].map(lambda x: x.lower().split(',') if isinstance(x, str) else 0)
#
#     # Create a full list of all words in all cells
#     list_words = [item for item in tempdf.iloc[:,1:].map(lambda x: x if isinstance(x, list) else None).to_numpy().flatten() if item is not None]
#
#     return list_words

# %% [raw]
# # OLD VERSION WORDLISTGEN
# def wordlistgen(df, start):
#     # This function aims to return a list of words so that 2-word words can be manually detected for a later function to add an underscore between them so tokenization recognises it as one word.
#
#     # Create a temporary dict within the function to work on
#     tempdf = df.copy()
#
#     # Loop through columns from the start point onwards
#     for i in tempdf.columns[start:]:
#
#         # Create new column to hold split values
#         # lowercase each cell's words and split by ',', returning the list container to the cell. Only if the cell is a str. Otherwise return 0 to the cell.
#         tempdf[i+' split'] = tempdf.apply(lambda row: row[i].lower().split(',') if isinstance(row[i], str) else 0, axis = 1)
#
#         # Drop the original column, replace with the split column and rename as original
#         tempdf.drop(i, axis = 1, inplace = True)
#         tempdf.rename(columns = {i+' split': i}, inplace = True)
#
#     # Create a full list of all words in all cells
#     list_words = [item for item in tempdf.iloc[:,1:].map(lambda x: x if isinstance(x, list) else None).to_numpy().flatten() if item is not None]
#
#     return list_words

# %% [markdown]
# def replacer(df, start):
#     # This function aims to go through the df and replace detected 2-word words with its underscored variant
#
#     # Create a temporary dict within the function to work on
#     tempdf = df.copy()
#
#     # Lowercase the df
#     tempdf.iloc[:,start:] = tempdf.iloc[:,start:].map(lambda x: x.lower() if isinstance(x, str) else 0)
#
#     # Replace words
#     tempdf.iloc[:,start:] = tempdf.iloc[:,start:].replace(joinwords, regex = True)
#
#     return tempdf

# %% [raw]
# ulistwords = set()
# for i in listwords:
#     if len(i) > 1:
#         for j in i:
#             if j not in ulistwords:
#                 ulistwords.update(j)
#     else:
#         if i[0] not in ulistwords:
#             ulistwords.update(i)

# %% [raw]
# # OLD VERSION CLEANER
# def cleaner(df,start_column):
#     # This function aims to tokenise the set, filter out stopwords/punctuations ,etc. and translate any remaining words not captured by earlier machine translations.
#     # Will be assigned back to individual cell locations after
#
#     # Create a temporary dict within the function to work on
#     tempdf = df.copy()
#
#     # Loop through columns from the start point onwards
#     for i in tempdf.columns[start_column:]:
#
#         # lowercase each cell's words. Token out into individual words, returning the list container to the cell. Only if the cell is a str. Otherwise return 0 to the cell.
#         tempdf[i+' token'] = tempdf.apply(lambda row: nltk.word_tokenize(row[i].lower()) if isinstance(row[i], str) else 0, axis = 1)
#
#         # Filter out stopwords if cell is a list (due to tokenisation step) else return unedited cell value
#         # stop_words is a global set containing the words to filter. Has additional items such as punctuation from the base stopwords form
#         tempdf[i+' filtered'] = tempdf.apply(lambda row: [w for w in row[i+' token'] if not w in stop_words]
#                                              if isinstance(row[i+' token'], list) else row[i+' token'],
#                                              axis = 1)
#
#         # Search if cell word is in dict of translated word. Only if cell is a list (due to tokenisation step) otherwise return unedited cell value.
#         # translated_word is a global dict containing the word as keys and translations of the words as values
#         tempdf[i+' translate'] = tempdf.apply(lambda row: [translated_words[w] if w in translated_words.keys() else w for w in row[i+' filtered']]
#                                               if isinstance(row[i+' filtered'], list) else row[i+' filtered'],
#                                               axis = 1)
#
#         # Clear working columns and original column and replace with latest column
#         tempdf.drop([i, i+' token', i+' filtered'], axis = 1, inplace = True)
#         tempdf.rename(columns = {i+' translate': i}, inplace = True)
#
#
#     return tempdf

# %%
# Generate text to copy-paste and the table of text in the cloud
def textcheck(df, start, cols, colorcode, headname):

    listwords = wordlister(df, start, cols)
    
    # total = ((df['hP16'] == colorcode).sum())*len(cols)

    #print top 5 words in the format indicated
    print(f'{headname}', end = ' = ')
    for i, r in listwords.iloc[0:5].iterrows():
        print(f'{r['index'].capitalize()}', end = ' | ')

    # Newline for next set of top-5 words
    print('\n')

    # return list for access later
    return listwords

# %%
def cloudgenerator(df, start, cols, hsl, filename = 'test', size = 50, width = 1600, height = 800, dirname = 'test', wordlist = 'NA'):  
    tempdf = cleaner(df, start)
    listwords = wordlistnestgen(tempdf, cols)
    cloudstring = stringgetter(listwords)

    # tuple unpack hsl values
    hue, sat, lumil, lumiu = hsl
    
    # Set custom colour. The other args are currently unused but could be utilised to affect the color scheme. e.g. hue = len(word) * basehue to use word length to affect hue
    def color_func(word, font_size, position,orientation,random_state=None, **kwargs):
        if word in wordlist:
            return(f"hsl({hue}, {sat}%, {np.random.randint(lumil, lumiu)}%)")
        else:
            return(f"hsl({hue}, {sat}%, {np.random.randint(lumil, lumiu)}%)")
        
    wordcloud = WordCloud(font_path = 'Lato-Regular.ttf',width=width, height=height, collocations=False, max_words = size, background_color = 'white').generate(cloudstring)

    # Display the generated image:
    plt.figure(figsize=(20,10))
    plt.imshow(wordcloud.recolor(color_func = color_func), interpolation='bilinear')
    plt.axis("off")
    plt.savefig(f'Clouds/{dirname}/{filename}.png',bbox_inches='tight')
    plt.close()

# %%
for name in dfdict.keys():
    prs = Presentation(rf'Submissions\Food Colouring_WordCloud_{name}.pptx')
    
    page_id = {i+1 : slide.slide_id for i, slide in enumerate(prs.slides)}

    # First, go through the slides
    for k, v in page_id.items():
        # If slide index is registered as needing an image, go in
        if k in pptdirection.keys():
            # Iterate through the value (list) to place images one by one
            for i in pptdirection[k]:
                # Find and store the path of the wordcloud              
                wordcloud = rf'CLouds\{name}\{name+i}.png'
                text = ppttext[name+i]
                #place the wordcloud
                cloudplacer(v, wordcloud, i)
                #place the text
                pos = i.split('_')
                textplacer(v, ppttext[name+i], boxdirections[pos[2]], colordirections[pos[1]])
        else:
            continue

    prs.save(rf'Submissions\Food Colouring_WordCloud_{name}.pptx')

# %% [markdown]
# ## Emotions

# %%
emotionsdf = pd.read_excel(r'emotions_colours.xlsx', sheet_name = 'GLOBAL', skiprows = 10)

# %%
emotionsdf.head()
# Out:
#         Unnamed: 0  Global    APAC  Europe   LATAM America   China Indonesia  \
# 0              NaN     NaN     NaN     NaN     NaN     NaN     NaN       NaN
# 1  Unweighted Base    1110     334     443     222     111     112       111
# 2   Weighted Total    1111     333     444     222     111     111       111
# 3    Mystery (Net)  0.1546   0.205  0.1185  0.1501  0.1572  0.3135     0.163
# 4         Elegance  0.1054  0.1379  0.0949  0.0912  0.0778  0.1555    0.1432
#
#     India United Kingdom Germany  France  Brazil  Mexico United States Morocco
# 0     NaN            NaN     NaN     NaN     NaN     NaN           NaN     NaN
# 1     111            111     111     113     111     111           111     108
# 2     111            111     111     111     111     111           111     111
# 3  0.1385         0.1095   0.071  0.1104  0.1689  0.1313        0.1572  0.1831
# 4  0.1151         0.0705  0.0494  0.0852  0.1018  0.0806        0.0778  0.1744

# %%
emotionsdf.dropna(inplace = True)

# %%
emotionsdf.reset_index(inplace = True)
emotionsdf.drop('index', axis = 1, inplace = True)

# %%
emotionsdf
# Out:
#           Unnamed: 0  Global    APAC  Europe   LATAM America   China  \
# 0    Unweighted Base    1110     334     443     222     111     112
# 1     Weighted Total    1111     333     444     222     111     111
# 2      Mystery (Net)  0.1546   0.205  0.1185  0.1501  0.1572  0.3135
# 3           Elegance  0.1054  0.1379  0.0949  0.0912  0.0778  0.1555
# 4     Sophistication  0.0577  0.0847  0.0292  0.0589  0.0882  0.2036
# ..               ...     ...     ...     ...     ...     ...     ...
# 508        Happiness  0.0743  0.0986  0.0642  0.0482  0.0938   0.074
# 509              Joy  0.0582  0.0629  0.0511  0.0489  0.0911  0.0445
# 510       Positivity  0.1097  0.1153  0.1167  0.1076  0.0695  0.1094
# 511              Fun  0.0576  0.0617  0.0496  0.0647  0.0628  0.0797
# 512   TOTAL MENTIONS    4304    1410    1591     879     424     462
#
#     Indonesia   India United Kingdom Germany  France  Brazil  Mexico  \
# 0         111     111            111     111     113     111     111
# 1         111     111            111     111     111     111     111
# 2       0.163  0.1385         0.1095   0.071  0.1104  0.1689  0.1313
# 3      0.1432  0.1151         0.0705  0.0494  0.0852  0.1018  0.0806
# 4      0.0198  0.0307         0.0444  0.0305  0.0252  0.0671  0.0507
# ..        ...     ...            ...     ...     ...     ...     ...
# 508     0.113  0.1088         0.0438  0.0649  0.0496  0.0418  0.0546
# 509    0.0256  0.1186         0.0441  0.0872  0.0243  0.0469   0.051
# 510    0.0749  0.1616         0.0514  0.1688  0.1166  0.1152     0.1
# 511     0.022  0.0835         0.0736  0.0607  0.0464  0.0484   0.081
# 512       451     498            400     413     323     436     443
#
#     United States Morocco
# 0             111     108
# 1             111     111
# 2          0.1572  0.1831
# 3          0.0778  0.1744
# 4          0.0882  0.0166
# ..            ...     ...
# 508        0.0938  0.0984
# 509        0.0911  0.0488
# 510        0.0695  0.1299
# 511        0.0628  0.0178
# 512           424     456
#
# [513 rows x 16 columns]

# %%
# color keys
colororder = ['pink','yellow','blue','purple','orange','brown','black','red','green']

colordict = {}

# Iterate through excel and extract individual color dfs
counter = 0
for i in range(57,514,57):
    j = i-57
    colordict[colororder[counter]] = emotionsdf.iloc[j:i].copy()
    counter += 1

# %%
for k, v in colordict.items():
    v.reset_index(drop = True, inplace = True)
    v.drop([0,1,2,5,10,17,24,32,38,44,50,56], inplace = True)
    v.reset_index(drop = True, inplace = True)
    v.rename(columns = {'Unnamed: 0':'EMOTIONS','United Kingdom':'UK','United States':'US'}, inplace = True)
    v.rename(columns=str.upper, inplace = True)
    v.drop(['AMERICA'], axis = 1, inplace = True)
    colordict[k] = v.map(lambda x : round(x*10000) if isinstance(x, float) else x)

# %%
colordict['pink']
# Out:
#           EMOTIONS  GLOBAL  APAC  EUROPE  LATAM  CHINA  INDONESIA  INDIA  \
# 0         Elegance    1054  1379     949    912   1555       1432   1151
# 1   Sophistication     577   847     292    589   2036        198    307
# 2       Confidence     556   437     636    487    506        586    219
# 3            Power     304   329     227    241    348        134    504
# 4          Success     342   364     411    183    240        433    418
# 5            Trust     548   776     532    345    518       1017    793
# 6          Comfort     854   982     955    577   1027        441   1477
# 7       Naturality     928   932    1022    830    440       1115   1240
# 8          Organic     392   592     226    406    351        335   1091
# 9           Warmth    1065   890    1167   1105    805       1206    658
# 10      Simplicity     598   788     476    640    638       1015    712
# 11           Clean     625   850     567    366    710        748   1091
# 12         Harmony     970   606     897   1692    748        765    305
# 13         Healthy     978  1133     925    716    549        635   2215
# 14         Loyalty     355   578     231    306    490        968    276
# 15            Luck     306   451     294    263    958        201    195
# 16      Prosperity     353   330     435    265    549         61    378
# 17          Safety     339   427     346    242    437        253    590
# 18         Freedom     420   530     353    411    537        614    439
# 19        Optimism     528   731     553    385   1071        628    496
# 20        Pleasure    1173  1311    1181   1095   1407       1206   1319
# 21        Youthful    1404  1544    1234   1615   1093       2574    964
# 22          Energy     700   846     658    418   1122        659    759
# 23      Refreshing    1045  1709     853    548    924       1903   2301
# 24       Freshness    1133  1177    1176   1415    854       1195   1483
# 25            Calm     980  1013    1084    943    887        966   1187
# 26      Creativity    1062  1083     967   1294    705       1090   1453
# 27        Feminity    2838  2621    2959   3161   3077       2824   1963
# 28        Softness    2426  2157    2529   2866   1512       3025   1935
# 29         Passion    1008   866     916   1271   1027        896    676
# 30         Fantasy    1546  1544    1403   2209   2519       1130    984
# 31     Imagination     805   780     545   1137   1186        495    658
# 32         Mystery     408   283     377    516    520        233     96
# 33         Royalty     393   439     275    492    259        218    841
# 34          Luxury     446   402     523    334    266        246    694
# 35          Action     180   108     163    204      0        242     83
# 36       Adventure     404   388     358    383    476        457    231
# 37      Excitement     590   494     645    501    240        430    811
# 38            Love    2635  2863    2436   2553   2066       3350   3174
# 39        Strength     387   337     371    389    269         70    672
# 40       Curiosity     789   613     784   1316    834        932     72
# 41       Happiness    1459  1743    1467   1085   1465       1510   2253
# 42             Joy    1186  1066    1217   1379    976        756   1466
# 43      Positivity     989  1033     998    673    523        473   2102
# 44             Fun    1013   709    1226    964    763        694    670
#
#       UK  GERMANY  FRANCE  BRAZIL  MEXICO    US  MOROCCO
# 0    705      494     852    1018     806   778     1744
# 1    444      305     252     671     507   882      166
# 2    967      866     454     386     588   726      258
# 3    246      117      83     396      85   667      460
# 4    299      447     425     288      77   319      473
# 5    117      607     953     321     368   334      450
# 6    742      534    1147     774     380   625     1396
# 7    745     1128    1021     652    1008   732     1196
# 8    370      276     166     483     329   428       92
# 9   1875     1126     182     679    1531  1101     1484
# 10   413      316     697     629     651   427      478
# 11   473      287     506     476     256   704     1001
# 12   932     1603     677    1446    1938   911      374
# 13   450     1214     970     847     586  1254     1064
# 14   431      143     176     369     244   278      175
# 15    60      699     163      86     440     0      255
# 16   294      283      67     179     351   267     1096
# 17   379      165     273     262     223   244      568
# 18   371      251     434     545     277   381      353
# 19   516      329     180     355     416    98     1187
# 20   909     1038    2029     876    1315   882      747
# 21  1206     1611     675    1307    1923  1242     1444
# 22   778      852     468     637     200   993      535
# 23   598     1077     370     564     532   815     1366
# 24   858     1606     924    1465    1366   259     1315
# 25   815      973     820     913     973   540     1730
# 26  1096     1517     501    1011    1577   911      755
# 27  3089     2211    2299    3165    3157  2356     4239
# 28  2657     1378    2933    2513    3219  1941     3147
# 29  1366     1132     876    1425    1116  1274      289
# 30  1121     2653     825    1853    2565   796     1013
# 31  1069      385     462    1337     936  1257      264
# 32   512      267     416     428     603   697      312
# 33   496      152     180     677     306   534      271
# 34   625      243     318     668       0   493      908
# 35   174      103     283     165     242   417       94
# 36   321      260     655     304     461   678      194
# 37   296      324     565     486     515   835     1393
# 38  3222     2452    2018    3079    2027  2908     2053
# 39   330      576     213     494     283   602      366
# 40   686     1403     774     978    1654   288      272
# 41  2097     1079     988    1163    1007  1328     1704
# 42  1033     1363     815    1786     972  1037     1657
# 43  1161     1139     466     976     369  1456     1227
# 44  1322     1562    1263     889    1039  1175      757

# %%
emotionsdirections = {# PINK
             'pink':((340, 100, 59.8, (78, 80)), 50, 1600, 800, 1),
             # YELLOW
             'yellow':((45, 100, 50, (80, 90)), 50, 1600, 800, 2),
             # BLUE
             'blue':((235, 100, 50, (80, 90)), 50, 1600, 800, 3),
             # PURPLE
             'purple':((264, 31.4, 52, (264, 31.1, 76, 77)), 50, 1600, 800, 4),
             # ORANGE
             'orange':((30, 100, 50, (80, 90)), 50, 1600, 800, 5),
             # BROWN
             'brown':((30, 100, 25, (80, 90)), 50, 1600, 800, 6),
             # BLACK
             'black':((0, 0, 0, (60, 70)), 50, 1600, 800, 7),
             # RED
             'red':((0, 100, 50, (70, 80)), 50, 1600, 800, 8),
             # GREEN
             'green':((143, 76.5, 33.3, (120, 38.2, 73, 74)), 50, 1600, 800, 9),
}

regiondirections = {'GLOBAL':1
          ,'APAC':2
          ,'EUROPE':3
          ,'LATAM':4
          ,'CHINA':5
          ,'INDONESIA':6
          ,'INDIA':7
          ,'UK':8
          ,'GERMANY':9
          ,'FRANCE':10
          ,'BRAZIL':11
          ,'MEXICO':12
          ,'US':13
          ,'MOROCCO':14
}

# %%
def cloudgeneratoremotion(freqdict, hsl, filename = 'test', size = 50, width = 1600, height = 800, dirname = 'test', wordlist = 'NA'):

    # tuple unpack hsl values
    hue, sat, lumibright, lumirand = hsl
    if len(lumirand) == 2:
        hue2, sat2 = hue, sat
        lumil, lumiu = lumirand
    else:
        hue2, sat2, lumil, lumiu = lumirand
    
    # Set custom colour. The other args are currently unused but could be utilised to affect the color scheme. e.g. hue = len(word) * basehue to use word length to affect hue
    def color_func(word, font_size, position,orientation,random_state=None, **kwargs):
        if word in wordlist:
            return(f"hsl({hue}, {sat}%, {lumibright}%)")
        else:
            return(f"hsl({hue2}, {sat2}%, {np.random.randint(lumil , lumiu)}%)")
        
    wordcloud = WordCloud(font_path = 'Lato-Regular.ttf', width=width, height=height, collocations=False, max_words = size, background_color = 'white', normalize_plurals = False).generate_from_frequencies(freqdict)

    # Display the generated image:
    plt.figure(figsize=(20,10))
    plt.imshow(wordcloud.recolor(color_func = color_func), interpolation='bilinear')
    plt.axis("off")
    plt.savefig(f'Clouds/Emotions/{dirname}/{filename}.png',bbox_inches='tight')
    plt.close()

# %%
# Creates the word frequency dictionary for one color in one region

def wordfreqcreator(colordict, color, col):
    # Access df based on color key
    v = colordict[color]
    # Initialise word frequencies dictionary
    wordfreq = {}
    # Loop through rows and save freq to dict
    for i in range(len(v.index)):
        # [i,0] is the emotion, [i,col] is the respective frequency depending on region
        wordfreq[v.iloc[i,0]] = v.iloc[i,col]

    # get top 5 words
    sorted_wordfreq = dict(sorted(wordfreq.items(), key=lambda x:x[1], reverse = True))
    top5 = list(sorted_wordfreq.keys())[0:5]
    
    return wordfreq, top5

# %%
# main code for emotions
for k, v in regiondirections.items():
    for k2, v2 in emotionsdirections.items():
        wordfrequecies, top5words = wordfreqcreator(colordict, k2, v)

        cloudgeneratoremotion(wordfrequecies, v2[0], k2, v2[1], v2[2], v2[3], k, top5words)

# %%
len(colordict['green'].index)
# Out:
# 45

# %%
sorted_wordfreq = dict(sorted(regiondirections.items(), key=lambda x:x[1], reverse = True))

# %%
list(sorted_wordfreq.keys())[0:5]
# Out:
# ['MOROCCO', 'US', 'MEXICO', 'BRAZIL', 'FRANCE']

# %%
colordict['brown']
# Out:
#           EMOTIONS  GLOBAL  APAC  EUROPE  LATAM  CHINA  INDONESIA  INDIA  \
# 0         Elegance     669   646     609    992    937        220    781
# 1   Sophistication     677   815     376   1202   1378        294    773
# 2       Confidence     652  1137     350    608   1069        556   1786
# 3            Power     757   867     704    817   1284        171   1148
# 4          Success     335   363     379    187    261        239    591
# 5            Trust     681   609     735    775    770        435    623
# 6          Comfort    1104  1278     978    764    952       1372   1511
# 7       Naturality    1700  1504    1798   1537    725       1301   2488
# 8          Organic    1710  1455    1550   2243   1398        726   2241
# 9           Warmth    1842  1704    2057   1456   1083       2274   1756
# 10      Simplicity    1160   904    1380   1086    823       1424    465
# 11           Clean     596   753     593    336    698        396   1164
# 12         Harmony     535   746     505    456    878       1037    323
# 13         Healthy    1079  1562     810   1038   1488        493   2705
# 14         Loyalty     463   812     276    261    805        920    712
# 15            Luck     308   271     252    432    579        233      0
# 16      Prosperity     321   420     270    235    710        436    115
# 17          Safety     521   621     443    476    751        205    906
# 18         Freedom     318   463     226    259    514        493    381
# 19        Optimism     483   815     266    392    977        882    585
# 20        Pleasure     809  1283     558    700    249       2692    907
# 21        Youthful     364   507     296    246    779        384    357
# 22          Energy     923  1181     898    697    650       1532   1361
# 23      Refreshing     598   916     451    378    495        626   1629
# 24       Freshness     769  1101     583    661    937        554   1810
# 25            Calm    1017  1166    1107    676    919       1675    903
# 26      Creativity     753   948     561   1155   1301        726    817
# 27        Feminity     304   550     197    138   1177        288    185
# 28        Softness     616   715     550    662    937        867    342
# 29         Passion     616  1169     461    286    874       1378   1254
# 30         Fantasy     513   710     428    522    755        676    699
# 31     Imagination     526   519     566    531    250        879    429
# 32         Mystery    1691  1404    1687   2472   1622       1561   1030
# 33         Royalty     335   552     304    180    419        255    982
# 34          Luxury     536   963     244    540   1165       1042    682
# 35          Action     375   331     327    489    395        423    174
# 36       Adventure     853   774    1104    629    912        556    853
# 37      Excitement     547   803     397    311    642        955    813
# 38            Love     346   623     283    152    648        512    708
# 39        Strength    1429  1285    1746   1255   1146        762   1945
# 40       Curiosity    1050   873    1019   1495   1334        522    764
# 41       Happiness     502   838     389    285    896        672    945
# 42             Joy     411   836     258     86    760        606   1142
# 43      Positivity     399   746     198    216    737        862    639
# 44             Fun     400   586     252    305   1196        236    327
#
#       UK  GERMANY  FRANCE  BRAZIL  MEXICO    US  MOROCCO
# 0    323      669     253     957    1026   328     1192
# 1    423      894      93    1432     971   413       94
# 2    879      289      76     419     797   497      155
# 3    688      304      96     998     636   517     1729
# 4    211      516     499     275     100   370      292
# 5    500      762     525    1094     457   494     1153
# 6   1516     1061     690     601     928  1760      645
# 7   2571     1728    1151    1961    1112  2226     1741
# 8   1964     2271     687    2975    1512  2054     1276
# 9   1641     2223    1643    1101    1810  2166     2720
# 10  1201     2015     707    1069    1103  1196     1597
# 11   418     1523     114     189     483   661      317
# 12   308      732     339     632     280   185      639
# 13   951      680     413    1037    1039   789     1197
# 14   176      498     258     162     361   567      171
# 15   240      407     182     524     339   400      179
# 16   255      524     103     206     263   397      200
# 17   510      563     259     253     699   628      439
# 18   172      377      96     334     184   365      260
# 19   356      257      85     328     457   541      364
# 20   685      301     786     688     712   612      458
# 21   273      292     363     195     298   447      257
# 22   544     1161     586     887     507   705     1299
# 23   215      529     308     359     397   670      752
# 24   769      163     943     359     964   730      456
# 25  1125     1594     829     521     831   893      880
# 26   489      863     168    1252    1059   134      722
# 27   216      348      69     277       0   330      155
# 28   799      428     533     692     632   495      439
# 29   224      683     112     175     398   239      825
# 30   257      358     176     480     563   242      921
# 31   281      476     645     445     617   375      863
# 32  1376      614    2032    2129    2815  1010     2726
# 33   308      222      75     361       0   122      611
# 34    77      312     211     610     471   417      375
# 35   133      407     682     693     284   475       86
# 36  1773      512     648     747     512   532     1483
# 37   176      510     100     169     453   850      801
# 38   306      443       0     259      45   159      384
# 39   982     1826    1867    1903     607   941     2309
# 40  1117      418    1268    1197    1793   813     1274
# 41   165      742     269     190     381   383      379
# 42   269      415     251       0     172   403       96
# 43   112       88     334     341      90   530      257
# 44   182      268     171     468     142   622      388
